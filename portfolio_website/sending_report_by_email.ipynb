# %%
import fundamentus

df = fundamentus.get_resultado()
filtro = df[(df.pl > 0) & (df.dy > 0.05) & (df.mrgebit > 0.3)]
filtro.sort_values('dy', ascending = False, inplace = True)
filtro
# Out:
# 2024-05-14 08:14:58,236 [logging.log_init] INFO: LOGLEVEL=INFO
# /tmp/ipykernel_324073/941647672.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtro.sort_values('dy', ascending = False, inplace = True)
# Multiples  cotacao     pl   pvp    psr      dy     pa    pcg  pebit   pacl  \
# papel
# TRPN3         0.71   0.44  0.54  0.263  1.0474  0.399   0.59   0.36   0.59
# PETR4        41.62   4.93  1.33  1.107  0.1750  0.509  44.91   2.43  -1.10
# PETR3        44.14   5.23  1.41  1.174  0.1650  0.539  47.63   2.58  -1.17
# VALE3        64.67   7.58  1.57  1.424  0.1081  0.641  31.75   3.56  -1.67
# EQPA3         7.45   7.39  3.54  1.586  0.1020  1.153  11.94   5.23  -3.09
# TAEE3        11.55  10.66  1.69  3.510  0.0952  0.608  17.33   6.23  -1.30
# ...

# %%
import pandas as pd

# Supondo que df é o DataFrame carregado da imagem
# df = pd.read_csv('seu_arquivo.csv')

for index, row in filtro.iterrows():
    print(f"Índice: {index}")
    print('---')
    print(f"Row: {row}")
    print('---')
    print(f"Cotação: {row['cotacao']}")
    print('---')
    # Acessar outras colunas conforme necessário
    print(f"PL: {row['pl']}")
    print('---')
    print('---')
# Out:
# Índice: TRPN3
# ---
# Row: Multiples
# cotacao     7.100000e-01
# pl          4.400000e-01
# pvp         5.400000e-01
# psr         2.630000e-01
# dy          1.047400e+00
# pa          3.990000e-01
# pcg         5.900000e-01
# pebit       3.600000e-01
# pacl        5.900000e-01
# evebit     -3.500000e-01
# evebitda   -3.500000e-01
# mrgebit     7.228000e-01
# mrgliq      5.929000e-01
# roic        5.230100e+00
# roe         1.223500e+00
# liqc        3.610000e+00
# liq2m       0.000000e+00
# patrliq     5.935800e+07
# divbpatr    0.000000e+00
# c5y         5.770000e-02
# Name: TRPN3, dtype: float64
# ---
# Cotação: 0.71
# ---
# PL: 0.44
# ---
# ---
# Índice: PETR4
# ---
# Row: Multiples
# cotacao     4.162000e+01
# pl          4.930000e+00
# pvp         1.330000e+00
# psr         1.107000e+00
# dy          1.750000e-01
# pa          5.090000e-01
# pcg         4.491000e+01
# pebit       2.430000e+00
# pacl       -1.100000e+00
# evebit      3.440000e+00
# evebitda    2.580000e+00
# ...
